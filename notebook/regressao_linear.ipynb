# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import kagglehub
from sklearn.linear_model import LinearRegression

# %%
path = kagglehub.dataset_download("abhishek14398/salary-dataset-simple-linear-regression")
# carrega dataset do kaggle
df = pd.read_csv(f"{path}/Salary_dataset.csv")

# %%
# 5 primeiras linhas
df.head()
# Out:
#    Unnamed: 0  YearsExperience   Salary
# 0           0              1.2  39344.0
# 1           1              1.4  46206.0
# 2           2              1.6  37732.0
# 3           3              2.1  43526.0
# 4           4              2.3  39892.0

# %%
df.isnull().sum()
# verifica se tem nulo
# Out:
# Unnamed: 0         0
# YearsExperience    0
# Salary             0
# dtype: int64

# %%
df.shape
# taamnho dataset
# Out:
# (30, 3)

# %%
x = df[['YearsExperience']]
y = df['Salary']
#separa as features

# %%
y
# Out:
# 0      39344.0
# 1      46206.0
# 2      37732.0
# 3      43526.0
# 4      39892.0
# 5      56643.0
# 6      60151.0
# 7      54446.0
# 8      64446.0
# 9      57190.0
# 10     63219.0
# 11     55795.0
# 12     56958.0
# 13     57082.0
# 14     61112.0
# 15     67939.0
# 16     66030.0
# 17     83089.0
# 18     81364.0
# 19     93941.0
# 20     91739.0
# 21     98274.0
# 22    101303.0
# 23    113813.0
# 24    109432.0
# 25    105583.0
# 26    116970.0
# 27    112636.0
# 28    122392.0
# 29    121873.0
# Name: Salary, dtype: float64

# %%
model = LinearRegression()
model = model.fit(x,y)
#treina o modelo com os dados

# %%
model.predict([[1.4], [2.5], [3.8]])
# faz prediçoes
# com base nos anos de experiencia quaal o salario dele
# Out:
# /home/beuren/anaconda3/lib/python3.13/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([38078.15121656, 48473.10977016, 60758.06078805])
